# %% [markdown]
# Hi again..
#
# I am find new source for python and data science.
#
# Trying at now step by step.
#
# Contact at from [Page Link.](https://github.com/timucinaydogdu) or <a href="tim.aydogdu@gmail.com">Mail :</a>tim.aydogdu@gmail.com
#
# Again basics...

# %%
print(3+5)
# Out:
# 8

# %%
print("Result : ",3+5)
# Out:
# Result :  8

# %%
print("Welcome to new world !!!")
# Out:
# Welcome to new world !!!

# %%
print ('Your selection."Double" or "Single" use str mark ')
# Out:
# Your selection."Double" or "Single" use str mark

# %%
print ("""
If your choose multiline write code pick this third way.
""")
# Out:
# If your choose multiline write code pick this third way.

# %%
print ("Weather" , 15 , "C")
print ("Weather" , 15 , "C", sep="+") # Sep change space than "str" value.
# Out:
# Weather 15 C
# Weather+15+C

# %%
print("Fruit", end=" ")
print("Vegetables", end=" ") # End def value has /n. /n end of line. Now outputs dont make new line.
# Out:
# Fruit Vegetables

# %%
a= 1         # Integer data type 
a= 1.0       # Float data type
a= "a = string data type"
a= True      # Boolean data type

# %% [markdown]
# Little Calculate

# %%
pi =3.14
r = 4
print("Circle Length :", 2*pi*r,"cm")
# Out:
# Circle Length : 25.12 cm

# %%
Jen=Mar=May= 31  # Multi variables

# %% [markdown]
# Data Types

# %%
score = 42
print("Finel Exam Score : ",score,type(score))  # Type module show variable type.
# Out:
# Finel Exam Score :  42 <class 'int'>

# %%
a=22
b=15
print("Sum",a+b)
print("Sub",a-b)
print("Div",a/b,type(a/b))  # Return Value type float
print("Mul",a*b)
print("Pow",a**b)
# Out:
# Sum 37
# Sub 7
# Div 1.4666666666666666 <class 'float'>
# Mul 330
# Pow 136880068015412051968

# %%
fruit = "Orange"
vegetables = "Tomato"
print("Word           : ",fruit,len(fruit)) # Len module show variable type. 
print("1.Character    : ",fruit[0])
print("2.Character    : ",fruit[1])
print("3-5.Character  : ",fruit[2:5])
print("3-Full Char    : ",fruit[2:])
print(fruit+vegetables)
print(len(fruit+vegetables)*"--")          # Use len with make - with *
# Out:
# Word           :  Orange 6
# 1.Character    :  O
# 2.Character    :  r
# 3-5.Character  :  ang
# 3-Full Char    :  ange
# OrangeTomato
# ------------------------

# %%
print ("{2} {0} {1} {3}".format("Data Scientist In"   ,6,     "We Will Be","Monts"))  # Format sample in with string type
###                                  index[0]       index[1]    index[2]    index[3]  ###
# Out:
# We Will Be Data Scientist In 6 Monts

# %%
pi=3.14159265359
print("Pi : {}".format(pi))
print("Pi : {:.3f}".format(pi))
print("Pi : {:.4f}".format(pi))
print("Pi : {:.5f}".format(pi))
# Out:
# Pi : 3.14159265359
# Pi : 3.142
# Pi : 3.1416
# Pi : 3.14159

# %%
name = input('Your Name : ')
age  = input('Your Age  : ') 
print("-"*35)
print ("Your name is  {} and {} age old.".format(ad,yas))
# Out:
# Your Name : Timuçin
# Your Age  : 35
# -----------------------------------
# Your name is  Timuçin and 35 age old.

# %% [markdown]
# Comparasion Operants = Return Result Boolean
#
# ### == If Equal
# ### != If Not Equal
# ### >  Bigger
# ### >= Equal and bigger
# ### <= Equal and lowwer

# %%
a = 42
b = "10"
c = "1.5"
d = "Apple"

print(a-int(b))
print(a-float(c))
print(d+str(a))
# Out:
# 32
# 40.5
# Apple42

# %% [markdown]
# # Home Work

# %%
### Data jarlabs Python Basics Home Work 1-2 
principalamount= 1000
interest_rate = 12
interes_date = 7
f=(principalamount*((1+interest_rate/100)**interes_date))-principalamount
totalamount=principalamount+f
print("Principal Amount : ", principalamount," $")
print("--"*30)
print("7 Days Interest Amount : {:.2f} $  Total Amounts : {:.2f} $".format(f,totalamount))
print("--"*30)
print("""Hafta başında {} dolarlık bitcoin aldığımızda günde ortalama %{} kazançla, 
bir hafta sonunda {:.2f} dolar kazanırdık""".format(principalamount,interest_rate,f))
# Out:
# Principal Amount :  1000  $
# ------------------------------------------------------------
# 7 Days Interest Amount : 1210.68 $  Total Amounts : 2210.68 $
# ------------------------------------------------------------
# Hafta başında 1000 dolarlık bitcoin aldığımızda günde ortalama %12 kazançla,
# bir hafta sonunda 1210.68 dolar kazanırdık

# %%
### Data jarlabs Python Basics Home Work 3
fname=input("Enter file name : ")
print(fname,"py",sep=".")
# Out:
# Enter file name : Pythonbasics
# Pythonbasics.py
